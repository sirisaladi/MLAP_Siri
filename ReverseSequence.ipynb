# %% [markdown]
# # Reverse Sequence

# %%
x=int(input("enter a number"))
i=1
while x>=i:
    temp=1
    while temp<=x:
        print("*",end='')
        temp=temp+1
    x=x-1
    print('\n')
# Out:
# enter a number40
# ****************************************
#
# ***************************************
#
# **************************************
#
# *************************************
#
# ************************************
#
# ***********************************
#
# **********************************
#
# *********************************
#
# ********************************
#
# *******************************
#
# ******************************
#
# *****************************
#
# ****************************
#
# ***************************
#
# **************************
#
# *************************
#
# ************************
#
# ***********************
#
# **********************
#
# *********************
#
# ********************
#
# *******************
#
# ******************
#
# *****************
#
# ****************
#
# ***************
#
# **************
#
# *************
#
# ************
#
# ***********
#
# **********
#
# *********
#
# ********
#
# *******
#
# ******
#
# ...
